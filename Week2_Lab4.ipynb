# %%
from PIL import Image
 
img = Image.open('julian.jpg')
img.show() # show the images

# %%
# extact red, green, blue, channel
r, g, b = img.split()

# check the length of red feature
print(len(r.histogram()))

# Print the historgram of red channel
print(r.histogram())
# Out:
# 256
# ...
